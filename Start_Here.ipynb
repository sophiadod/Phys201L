# %% [markdown]
# # PHYS 201L GitHub and Colab setup check
#
# This exercise confirms that your team can open a notebook from its shared GitHub fork, run it in Colab, save it back to the correct path, and verify the resulting commit.
#
# Before continuing, complete the repository's [Getting Started guide](https://github.com/brash99/Phys201L/blob/main/GETTING_STARTED.md). That guide explains account creation, the one-fork-per-team rule, collaborator invitations, invitation acceptance, and Colab authorization.

# %% [markdown]
# ## Stop and verify the repository
#
# Look at the browser address from which you opened this notebook. Before doing any work, confirm all of the following:
#
# - The repository owner is your team's **repository manager**, not `brash99`.
# - The repository name is `Phys201L`.
# - Every team member has accepted the collaborator invitation.
# - Your team has only one shared fork.
#
# If any statement is false or uncertain, stop and use the [Getting Started guide](https://github.com/brash99/Phys201L/blob/main/GETTING_STARTED.md) before continuing.

# %% [markdown]
# ## Team information
#
# Replace the prompts below with your information.
#
# **Team name:** YOUR TEAM NAME
# **Team members:** TEAM MEMBER NAMES
# **Repository manager:** REPOSITORY MANAGER NAME

# %%
team_name = "Replace this text with your team name"
print(f"GitHub and Colab are ready for {team_name}!")

# %% [markdown]
# ## Save test
#
# 1. Replace every team-information prompt and update `team_name` in the code cell.
# 2. Run the code cell and confirm that the team's name appears in its output.
# 3. In Colab, select **File -> Save a copy in GitHub**.
# 4. If prompted, authorize Colab to access the same GitHub account that accepted the team invitation.
# 5. In the save dialog, choose the repository manager's `Phys201L` fork and branch `main`.
# 6. Keep the original path `Start_Here.ipynb`. Do not add `Copy of` or change the filename.
# 7. Use the commit message `Complete Colab save test` and save.
# 8. Return to the team fork on GitHub and refresh the page.
# 9. Open `Start_Here.ipynb` and verify that the names, code output, and new commit are visible.
#
# The check is complete only when the saved changes are visible on GitHub. If the fork is missing from the Colab save dialog, confirm that the collaborator invitation was accepted and that Colab was authorized with the correct GitHub account.

# %% [markdown]
# ## Next: open Lab 1 safely
#
# After the save test succeeds:
#
# 1. Return to the team's fork on GitHub.
# 2. Open `labs/Lab01_Density/Lab01_Density.ipynb`.
# 3. Open that notebook in Colab.
# 4. Enter every team member's name.
# 5. Save an immediate test commit to the original path before entering substantial data.
# 6. Verify the test commit on GitHub.
#
# Never save the team's work to `brash99/Phys201L`, a second personal fork, Google Drive, or a renamed notebook. If GitHub reports a conflict, stop and ask the instructor before deleting or overwriting anything.
